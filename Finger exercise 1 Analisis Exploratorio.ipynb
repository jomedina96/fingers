# %%
#importo las bibliotecas 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#abro el archivo
datos=pd.read_csv("events.csv", low_memory=False)

# %%
#obtengo una primera descripcion del archivo
datos.describe()
# Out:
#                   timestamp           event    person    url     sku  \
# count               1011288         1011288   1011288  82756  563838
# unique               793805              11     27624    227    3574
# top     2018-05-15 15:56:06  viewed product  71492f2b      /  2830.0
# freq                     11          528931      2771  28323    4282
#
#            model condition storage   color  \
# count     564284    563836  563836  563836
# unique       202         5       8      63
# top     iPhone 6       Bom    16GB   Preto
# freq       50916    243014  190833  132960
#
#                                                      skus       ...        \
# count                                              221699       ...
# unique                                              35310       ...
# top     2820,6706,6720,2750,6649,7251,6663,12604,7224,...       ...
# freq                                                  594       ...
#
# ...

# %%
#leo como son las columnas
datos.head(10)
# Out:
#              timestamp            event    person                         url  \
# 0  2018-05-31 23:38:05  ad campaign hit  0004b0a2   /comprar/iphone/iphone-5s
# 1  2018-05-31 23:38:05     visited site  0004b0a2                         NaN
# 2  2018-05-31 23:38:09   viewed product  0004b0a2                         NaN
# 3  2018-05-31 23:38:40         checkout  0004b0a2                         NaN
# 4  2018-05-29 13:29:25   viewed product  0006a21a                         NaN
# 5  2018-05-29 13:29:26     visited site  0006a21a                         NaN
# 6  2018-05-29 13:29:27  ad campaign hit  0006a21a  /comprar/samsung/galaxy-s8
# 7  2018-05-29 13:29:35         checkout  0006a21a                         NaN
# 8  2018-04-09 20:12:31  generic listing  000a54b2                         NaN
# 9  2018-04-09 20:12:31     visited site  000a54b2                         NaN
#
#        sku              model condition storage           color  \
# ...

# %%
#problema 1
#valores distintos 
conteoDeEventos = datos["event"].value_counts().head(5)

# %%
g = sns.barplot(x=conteoDeEventos.values, y=conteoDeEventos.index, orient='h')
g.set_title("Eventos predominantes", fontsize=15)
g.set_xlabel("Frecuencia", fontsize=12)
g.set_ylabel("Tipo de evento", fontsize=12)
# Out:
# Text(0,0.5,'Tipo de evento')

# %%
#problema 2
d = datos.loc[datos['event'].str.contains("conversion")]
d = d.filter(["event","sku"])
conteoDeEventos = datos["sku"].value_counts().head(5)
g = sns.barplot(x=conteoDeEventos.values, y=conteoDeEventos.index, orient='h',order=conteoDeEventos.index)
g.set_title("Productos con mayor cantidad de conversiones. ", fontsize=15)
g.set_xlabel("Cantidad de conversiones", fontsize=12)
g.set_ylabel("Productos(SKU)", fontsize=12)
# Out:
# Text(0,0.5,'Productos(SKU)')

# %%
#problema 3
conteoDeEventos = datos["person"].value_counts().head(10)
g = sns.barplot(x=conteoDeEventos.values, y=conteoDeEventos.index, orient='h')
g.set_title("Usuarios con mayor actividad", fontsize=15)
g.set_xlabel("Cantidad de eventos", fontsize=12)
g.set_ylabel("Usuarios", fontsize=12)
# Out:
# Text(0,0.5,'Usuarios')
